# %% [markdown]
# # Week 1 notebook

# %%
import os
import sys
sys.path.insert(0, os.path.abspath('..'))

import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

from utils.load_config import load_config
from utils.show_image import show_image
from data_loader.data_loader_generic import DataLoaderGeneric
from models.model_wk1 import ModelWeek1

# %% [markdown]
# ## Load config
#
# load the config file for this notebook

# %%
config = load_config("../config/config_wk1_1.yml")
config
# Out:
# {'image_size': 50,
#  'epochs': 100,
#  'data_sets': {'week1_data_train': {'data_files': [{'file': '../data/A.m1.dir.tar.gz',
#      'labels': {0: 0},
#      'default_label': 1},
#     {'file': '../data/A.i.m1.dir.tar.gz', 'default_label': 2}]}},
#  'data_train_split': 0.8,
#  'data_validation_split': 0.8,
#  'data_batch_size': 32,
#  'data_num_classes': 3}

# %% [markdown]
# ## Create dataloader
#
# The dataset for this notebook is specified in the `week1_data_train` key in the config

# %%
data_loader = DataLoaderGeneric(config)

train_data_set, test_data_set, validation_data_set = data_loader.load_data_set("week1_data_train")

# %% [markdown]
# ## Create model
#
# create a model like
#
# ```
# model = Sequential([
#     Conv2D(32, kernel_size=(3, 3),activation='relu', input_shape=(image_size, image_size, 1)),
#     Conv2D(64, (3, 3), activation='relu'),
#     MaxPooling2D(pool_size=(2, 2)),
#     Dropout(0.25),
#     Flatten(),
#     Dense(128, activation='relu'),
#     Dropout(0.5),
#     Dense(num_classes, activation='softmax')
# ])
# ```

# %%
show_image(train_data_set)

# %%
model_wk1 = ModelWeek1(config)
model = model_wk1.get_uncompiled_model()
model = model_wk1.compile_model(model)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 48, 48, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 46, 46, 64)        18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 23, 23, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 23, 23, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 33856)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               4333696
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 4,352,899
# Trainable params: 4,352,899
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train model

# %%
epochs = min(config.get("epochs", 100), 40)

model.fit(
    train_data_set,
    steps_per_epoch=50,
    epochs=epochs,
    validation_data=validation_data_set,
    validation_steps=50,
    verbose=1,
)
# Out:
# Train for 50 steps, validate for 50 steps
# Epoch 1/40
# 50/50 [==============================] - 11s 214ms/step - loss: 0.9408 - accuracy: 0.6981 - val_loss: 0.9319 - val_accuracy: 0.7713
# Epoch 2/40
# 50/50 [==============================] - 10s 209ms/step - loss: 0.9347 - accuracy: 0.6969 - val_loss: 0.9295 - val_accuracy: 0.7656
# Epoch 3/40
# 50/50 [==============================] - 10s 208ms/step - loss: 0.9368 - accuracy: 0.7006 - val_loss: 0.9252 - val_accuracy: 0.7725
# Epoch 4/40
# 50/50 [==============================] - 10s 208ms/step - loss: 0.9273 - accuracy: 0.7250 - val_loss: 0.9233 - val_accuracy: 0.7669
# Epoch 5/40
# 50/50 [==============================] - 11s 218ms/step - loss: 0.9233 - accuracy: 0.7138 - val_loss: 0.9230 - val_accuracy: 0.7625
# Epoch 6/40
# 50/50 [==============================] - 12s 233ms/step - loss: 0.9269 - accuracy: 0.7119 - val_loss: 0.9157 - val_accuracy: 0.7756
# Epoch 7/40
# 50/50 [==============================] - 12s 234ms/step - loss: 0.9188 - accuracy: 0.7188 - val_loss: 0.9129 - val_accuracy: 0.7781
# Epoch 8/40
# 50/50 [==============================] - 12s 239ms/step - loss: 0.9117 - accuracy: 0.7188 - val_loss: 0.9111 - val_accuracy: 0.7725
# Epoch 9/40
# 50/50 [==============================] - 11s 218ms/step - loss: 0.9135 - accuracy: 0.7081 - val_loss: 0.9064 - val_accuracy: 0.7719
# Epoch 10/40
# 50/50 [==============================] - 10s 209ms/step - loss: 0.9106 - accuracy: 0.7063 - val_loss: 0.9039 - val_accuracy: 0.7731
# Epoch 11/40
# 50/50 [==============================] - 10s 208ms/step - loss: 0.9077 - accuracy: 0.7237 - val_loss: 0.8989 - val_accuracy: 0.7788
# Epoch 12/40
# 50/50 [==============================] - 10s 203ms/step - loss: 0.9037 - accuracy: 0.7169 - val_loss: 0.8954 - val_accuracy: 0.7819
# Epoch 13/40
# 50/50 [==============================] - 11s 211ms/step - loss: 0.8950 - accuracy: 0.7300 - val_loss: 0.8959 - val_accuracy: 0.7906
# Epoch 14/40
# 50/50 [==============================] - 11s 215ms/step - loss: 0.8954 - accuracy: 0.7350 - val_loss: 0.8907 - val_accuracy: 0.7731
# Epoch 15/40
# 50/50 [==============================] - 10s 200ms/step - loss: 0.8938 - accuracy: 0.7212 - val_loss: 0.8923 - val_accuracy: 0.7763
# Epoch 16/40
# 50/50 [==============================] - 11s 218ms/step - loss: 0.8985 - accuracy: 0.7050 - val_loss: 0.8884 - val_accuracy: 0.7775
# Epoch 17/40
# 50/50 [==============================] - 10s 199ms/step - loss: 0.8958 - accuracy: 0.7056 - val_loss: 0.8850 - val_accuracy: 0.7681
# Epoch 18/40
# 50/50 [==============================] - 10s 207ms/step - loss: 0.8861 - accuracy: 0.7350 - val_loss: 0.8814 - val_accuracy: 0.7806
# Epoch 19/40
# 50/50 [==============================] - 10s 201ms/step - loss: 0.8828 - accuracy: 0.7381 - val_loss: 0.8770 - val_accuracy: 0.7831
# Epoch 20/40
# 50/50 [==============================] - 11s 212ms/step - loss: 0.8745 - accuracy: 0.7412 - val_loss: 0.8758 - val_accuracy: 0.7844
# Epoch 21/40
# 50/50 [==============================] - 10s 206ms/step - loss: 0.8837 - accuracy: 0.7188 - val_loss: 0.8743 - val_accuracy: 0.7756
# Epoch 22/40
# 50/50 [==============================] - 10s 197ms/step - loss: 0.8726 - accuracy: 0.7419 - val_loss: 0.8708 - val_accuracy: 0.7856
# Epoch 23/40
# 50/50 [==============================] - 10s 197ms/step - loss: 0.8777 - accuracy: 0.7337 - val_loss: 0.8710 - val_accuracy: 0.7837
# Epoch 24/40
# 50/50 [==============================] - 10s 205ms/step - loss: 0.8705 - accuracy: 0.7281 - val_loss: 0.8684 - val_accuracy: 0.7831
# Epoch 25/40
# 50/50 [==============================] - 11s 215ms/step - loss: 0.8686 - accuracy: 0.7556 - val_loss: 0.8661 - val_accuracy: 0.7788
# Epoch 26/40
# 50/50 [==============================] - 10s 194ms/step - loss: 0.8699 - accuracy: 0.7375 - val_loss: 0.8640 - val_accuracy: 0.7738
# Epoch 27/40
# 50/50 [==============================] - 10s 197ms/step - loss: 0.8643 - accuracy: 0.7381 - val_loss: 0.8623 - val_accuracy: 0.7831
# Epoch 28/40
# 50/50 [==============================] - 10s 195ms/step - loss: 0.8688 - accuracy: 0.7325 - val_loss: 0.8615 - val_accuracy: 0.7769
# Epoch 29/40
# 50/50 [==============================] - 10s 201ms/step - loss: 0.8647 - accuracy: 0.7319 - val_loss: 0.8575 - val_accuracy: 0.7756
# Epoch 30/40
# 50/50 [==============================] - 10s 206ms/step - loss: 0.8619 - accuracy: 0.7456 - val_loss: 0.8541 - val_accuracy: 0.7725
# Epoch 31/40
# 50/50 [==============================] - 10s 194ms/step - loss: 0.8621 - accuracy: 0.7312 - val_loss: 0.8555 - val_accuracy: 0.7700
# Epoch 32/40
# 50/50 [==============================] - 10s 203ms/step - loss: 0.8597 - accuracy: 0.7375 - val_loss: 0.8541 - val_accuracy: 0.7763
# Epoch 33/40
# 50/50 [==============================] - 10s 196ms/step - loss: 0.8587 - accuracy: 0.7431 - val_loss: 0.8496 - val_accuracy: 0.7756
# Epoch 34/40
# 50/50 [==============================] - 10s 196ms/step - loss: 0.8535 - accuracy: 0.7550 - val_loss: 0.8460 - val_accuracy: 0.7862
# Epoch 35/40
# 50/50 [==============================] - 10s 203ms/step - loss: 0.8559 - accuracy: 0.7475 - val_loss: 0.8474 - val_accuracy: 0.7744
# Epoch 36/40
# 50/50 [==============================] - 12s 234ms/step - loss: 0.8462 - accuracy: 0.7688 - val_loss: 0.8428 - val_accuracy: 0.7744
# Epoch 37/40
# 50/50 [==============================] - 10s 201ms/step - loss: 0.8475 - accuracy: 0.7506 - val_loss: 0.8409 - val_accuracy: 0.7794
# Epoch 38/40
# 50/50 [==============================] - 10s 209ms/step - loss: 0.8386 - accuracy: 0.7719 - val_loss: 0.8386 - val_accuracy: 0.7769
# Epoch 39/40
# 50/50 [==============================] - 10s 204ms/step - loss: 0.8473 - accuracy: 0.7331 - val_loss: 0.8367 - val_accuracy: 0.7763
# Epoch 40/40
# 50/50 [==============================] - 10s 201ms/step - loss: 0.8504 - accuracy: 0.7419 - val_loss: 0.8371 - val_accuracy: 0.7725

# %%
model_wk1.save_model_and_weights_to_disk(model, "model_80.json", "model_80.h5")

# %% [markdown]
# ## Analyse Model

# %%
correct_labels = []
predicted_labels = []

for image, label in test_data_set:
    predicted = model.predict(image)

    for val in label.numpy(): correct_labels.append(val[0])
    for val in predicted: predicted_labels.append(np.argmax(val))
    # predicted_labels.append(predicted)

# %% [markdown]
# ### Plot confusion matrix
#
# It seems the model has trouble differentiating the isolated galaxy and a tidal interation

# %%
conf_mtrx = confusion_matrix(correct_labels, predicted_labels)
labels = ['TID', 'RPS', 'ISO']

fig, ax = plt.subplots(figsize=(10, 10))

# Using matshow here just because it sets the ticks up nicely. imshow is faster.
ax.matshow(conf_mtrx, cmap="Blues")

for (i, j), z in np.ndenumerate(conf_mtrx):
    ax.text(
        j,i, 
        '{:0.1f}'.format(z),
        ha='center',
        va='center',
        bbox=dict(boxstyle='round', facecolor='white', edgecolor='0.3'))

ax.set_xticklabels(['']+labels)
ax.set_yticklabels(['']+labels)
ax.set_xlabel("Predicted Label")
ax.set_ylabel("Actual Label")


plt.title("Confusion Matirx of Model")

plt.show()

# %%
# !rm -rf ./images

# %%
# !mkdir -p images

from PIL import Image 

counts = [0, 0, 0]

label_names = ["TID", "RPS", "ISO"]
for image, label in test_data_set:
    predicted = model.predict(image)

    for i in range(image.shape[0]):
        val = label[i].numpy()[0]
        pre_val = np.argmax(predicted[i])
        if val != pre_val:
            im_size = image[i].shape[0]
            img = image[i].numpy().reshape(im_size, im_size) * 255
            img = Image.fromarray(img).convert("L")
            counts[val] += 1
            img.save(f"images/val_{label_names[val]}__pre_{label_names[pre_val]}_{str(counts[val]).zfill(4)}.jpg")

print(counts)
# Out:
# [4, 40, 91]

# %%
import tarfile
import numpy as np

with tarfile.open("../data/A.m1.dir.tar.gz") as a:
    f = a.extractfile("m1.dir/2dftn1.dat")
    d = np.loadtxt(f, dtype=np.float32)

print(d[0])
# Out:
# 7.0845127

# %%
d = d.reshape(2000,50,50)

# %%
Image.fromarray(d[999]*255).convert("L")
# Out:
# <PIL.Image.Image image mode=L size=50x50 at 0x14C921208>
